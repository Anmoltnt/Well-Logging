# %% [markdown]
# <a href="https://colab.research.google.com/github/Anmoltnt/Well-Logging/blob/main/Well_Log.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('/content/log.csv')

# %% [markdown]
#  # Exploratory Data Analysis

# %%
df.head()
# Out:
#    Depth     RxoRt    RLL3       SP      RILD      MN      MI    MCAL    DCAL  \
# 0  195.0  226.0848  0.4076  69.8953  132.5052 -0.3548  0.1863  5.1090  1.8878
# 1  195.5  223.5031  0.4063  69.2303  123.6225 -0.3619  0.1867  5.1031  1.8882
# 2  196.0  221.4560  0.4047  68.4478  116.9258 -0.3668  0.1860  5.0872  1.8878
# 3  196.5  219.8248  0.4033  67.4843  111.7925 -0.3613  0.1867  5.0881  1.8884
# 4  197.0  218.1438  0.4023  66.3013  106.7821 -0.3569  0.1870  5.0972  1.8883
#
#      RHOB    RHOC     DPOR     CNLS       GR
# 0  1.6973 -0.6303  59.2216  30.0657  60.4576
# 1  1.6791 -0.6409  60.2877  26.7625  54.1495
# 2  1.6585 -0.6539  61.4914  27.6017  51.9944
# 3  1.6435 -0.6649  62.3711  31.5870  52.9645
# 4  1.6390 -0.6705  62.6343  35.8251  54.9659

# %%
#To check for null - The Dataset has no null values.
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    Depth     RxoRt    RLL3       SP      RILD      MN      MI    MCAL    DCAL  \
# 0  195.0  226.0848  0.4076  69.8953  132.5052 -0.3548  0.1863  5.1090  1.8878
# 1  195.5  223.5031  0.4063  69.2303  123.6225 -0.3619  0.1867  5.1031  1.8882
# 2  196.0  221.4560  0.4047  68.4478  116.9258 -0.3668  0.1860  5.0872  1.8878
# 3  196.5  219.8248  0.4033  67.4843  111.7925 -0.3613  0.1867  5.0881  1.8884
# 4  197.0  218.1438  0.4023  66.3013  106.7821 -0.3569  0.1870  5.0972  1.8883
#
#      RHOB    RHOC     DPOR     CNLS       GR
# 0  1.6973 -0.6303  59.2216  30.0657  60.4576
# 1  1.6791 -0.6409  60.2877  26.7625  54.1495
# 2  1.6585 -0.6539  61.4914  27.6017  51.9944
# 3  1.6435 -0.6649  62.3711  31.5870  52.9645
# 4  1.6390 -0.6705  62.6343  35.8251  54.9659

# %%
df.describe()
# Out:
#              Depth        RxoRt         RLL3           SP          RILD  \
# count  8739.000000  8739.000000  8739.000000  8739.000000   8739.000000
# mean   2535.727372   -18.493591    37.948919   -94.299762     34.511874
# std    1358.246302    31.420924    81.734581    39.652558    251.238360
# min     195.000000  -150.821900     0.389900  -201.623000      0.210400
# 25%    1292.250000   -31.993950     6.430800  -131.421100      4.356500
# 50%    2623.500000   -16.509300    12.138400   -95.587500      7.822900
# 75%    3715.750000    -5.941450    25.696300   -58.054000     19.486800
# max    4808.000000   247.583200   880.859400    69.895300  11510.641600
#
#                 MN           MI         MCAL         DCAL        RHOB  \
# count  8739.000000  8739.000000  8739.000000  8739.000000  8739.00000
# mean     11.714442    12.180632     5.906369     3.669944     2.03364
# std      27.537012    28.874862     1.305561     2.748873     0.41571
# ...

# %%
len(df[df['RILD'] >=2000])
# Out:
# 15

# %%
# sns.regplot(df['RHOB'],df['GR'])
sns.regplot(df['RxoRt'])
sns.regplot(df['SP'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-5880d5af7b3a> in <cell line: 2>()
#       1 # sns.regplot(df['RHOB'],df['GR'])
# ----> 2 sns.regplot(df['RxoRt'])
#       3 sns.regplot(df['SP'])
#
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py in regplot(data, x, y, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     745 ):
#     746
# --> 747     plotter = _RegressionPlotter(x, y, data, x_estimator, x_bins, x_ci,
#     748                                  scatter, fit_reg, ci, n_boot, units, seed,
#     749                                  order, logistic, lowess, robust, logx,
#
# ...

# %%
plt.style.use('default')
plt.figure(figsize=(4,8))


plt.plot(df['SP'],df['Depth'])

plt.ylim(5000,0)
plt.grid()

plt.axvline(x=-100,color='red')

# %%
plt.style.use('default')
plt.figure(figsize=(4,8))


plt.plot(np.log10(df['RILD']),df['Depth'],label='Deep Resistivity')
plt.plot(np.log10(df['RLL3']),df['Depth'],label='Shallow Resistivity')

plt.legend(loc ='upper right')

plt.axhspan(1500,2500,alpha=0.2,color='gold')

plt.ylim(5000,0)
plt.grid()

# %%
df.head()
# Out:
#    Depth     RxoRt    RLL3       SP      RILD      MN      MI    MCAL    DCAL  \
# 0  195.0  226.0848  0.4076  69.8953  132.5052 -0.3548  0.1863  5.1090  1.8878
# 1  195.5  223.5031  0.4063  69.2303  123.6225 -0.3619  0.1867  5.1031  1.8882
# 2  196.0  221.4560  0.4047  68.4478  116.9258 -0.3668  0.1860  5.0872  1.8878
# 3  196.5  219.8248  0.4033  67.4843  111.7925 -0.3613  0.1867  5.0881  1.8884
# 4  197.0  218.1438  0.4023  66.3013  106.7821 -0.3569  0.1870  5.0972  1.8883
#
#      RHOB    RHOC     DPOR     CNLS       GR
# 0  1.6973 -0.6303  59.2216  30.0657  60.4576
# 1  1.6791 -0.6409  60.2877  26.7625  54.1495
# 2  1.6585 -0.6539  61.4914  27.6017  51.9944
# 3  1.6435 -0.6649  62.3711  31.5870  52.9645
# 4  1.6390 -0.6705  62.6343  35.8251  54.9659

# %%
plt.style.use('default')
plt.figure(figsize=(4,8))


plt.plot(df['SP'],df['Depth'],label='SP')
plt.plot(df['GR'],df['Depth'],label='GR')

plt.axhspan(3800,4800,alpha=0.2,color='grey',label='Shale Bed')


plt.legend(loc ='upper right')

# plt.axhspan(1500,2500,alpha=0.2,color='gold')

plt.ylim(5000,0)
plt.grid()

# %%
grmax = max(df['GR'])
grmin = min(df['GR'])

# Gr = s*GRmax + (1-s)*GRmin
# s = (GR - GRMin)/(Grmax - Grmin)

# %%
df['Vsh'] = (df['GR'] - grmin)/(grmax - grmin)

# %%
plt.style.use('default')
plt.figure(figsize=(4,8))


# plt.plot(df['SP'],df['Depth'],label='SP')
plt.plot(df['GR'],df['Depth'],label='GR',alpha=0.2)
plt.plot(df['Vsh']*100,df['Depth'],label='Vsh')


plt.legend(loc ='upper right')

# plt.axhspan(1500,2500,alpha=0.2,color='gold')

plt.ylim(5000,0)
plt.grid()

# %%
# fig , ax = plt.subplots(nrows = 1 , ncols = 3,sharey=True)
# fig.set_figheight(10)
# fig.set_figwidth(15)

# ax[0].plot( df['SP'], df['Depth'])
# ax[0].grid()
# ax[0].set_ylim(5000,0)
# ax[0].set_title('SP Log')
# plt.grid()

# ax[0].plot( df['GR'], df['Depth'])
# ax[0].set_ylim(5000,0)
# ax[0].set_title('GR Log')
# plt.grid()

# plt.tight_layout()

# %%
plt.style.use('default')
plt.figure(figsize=(4,16))


plt.plot(df['DPOR'],df['Depth'],label='Density Porosity')
plt.plot(df['CNLS'],df['Depth'],label='Neutron Porosity')

# plt.axhspan(3800,4800,alpha=0.2,color='grey',label='Shale Bed')


plt.legend(loc ='upper right')

# plt.axhspan(1500,2500,alpha=0.2,color='gold')

plt.ylim(5000,0)
plt.grid()

# %%
plt.style.use('default')
plt.figure(figsize=(4,16))


plt.plot(df['RHOB'],df['Depth'],label='Density Porosity')
# plt.plot(df['CNLS'],df['Depth'],label='Neutron Porosity')

# plt.axhspan(3800,4800,alpha=0.2,color='grey',label='Shale Bed')


plt.legend(loc ='upper right')

# plt.axhspan(1500,2500,alpha=0.2,color='gold')

plt.ylim(5000,0)
plt.grid()

# %%
# plt.figure(figsize=(10,16))
fig, ax = plt.subplots(nrows= 1, ncols = 3)

ax[0].plot(df['GR'],df['Depth'])
ax[0].plot(df['SP'],df['Depth'])
ax[0].grid()

# %%
plt.style.use('default')
plt.figure(figsize=(4,16))


plt.plot(np.log(df['GR']),df['Depth'],label='Density Porosity')
plt.plot(df['DCAL'],df['Depth'],label='Caliper Log')

# plt.plot(df['CNLS'],df['Depth'],label='Neutron Porosity')

# plt.axhspan(3800,4800,alpha=0.2,color='grey',label='Shale Bed')


plt.legend(loc ='upper right')

# plt.axhspan(1500,2500,alpha=0.2,color='gold')

plt.ylim(5000,0)
plt.grid()

# %%
# plt.figure(figsize=(10,16))
fig, ax = plt.subplots(nrows= 1, ncols = 4,sharey=True)
# fig.set_figsize = (12,12)
fig.set_figheight(15)
fig.set_figwidth(15)

ax[0].plot(df['DCAL'],df['Depth'],label='Caliper')
# ax[0].plot(df['SP'],df['Depth'])
ax[0].set_ylim(5000,0)
ax[0].set_title('Caliper Log')
ax[0].axhspan(3500,5000,color='red',alpha=0.3,label='Wash-Out')
ax[0].legend()
ax[0].grid()


ax[1].plot(df['SP'],df['Depth'],label='SP')
ax[1].plot(df['GR'],df['Depth'],label='GR')
ax[1].legend(loc='upper center')
ax[1].set_title('Lithology Logs')
ax[1].axhspan(3500,5000,color='gold',alpha=0.3)
ax[1].grid()


ax[2].plot(np.log(df['RILD']),df['Depth'],label='RILD')
ax[2].plot(np.log(df['RLL3']),df['Depth'],label='RLL3')
ax[2].legend(loc='upper center')
ax[2].set_title('Resistivity Logs')
ax[2].axhspan(3500,5000,color='gold',alpha=0.3)
ax[2].axhspan(1500,2500,color='green',alpha=0.3)
ax[2].grid()



ax[3].plot(df['DPOR'],df['Depth'],label='DPOR',color='red')
ax[3].plot(df['CNLS'],df['Depth'],label='CNLS',color='purple')
ax[3].legend(loc='upper center')
ax[3].set_title('Porosity Logs')
ax[3].axhspan(3500,5000,color='black',alpha=0.1)
ax[3].axhspan(1500,2500,color='green',alpha=0.3)
ax[3].axhspan(2500,3500,color='orange',alpha=0.6)
# ax[3].set_xl
ax[3].grid()
